# %%
import os
# Step 1: Create folders
os.makedirs("templates", exist_ok=True)
os.makedirs("static/images", exist_ok=True)
os.makedirs("static/css", exist_ok=True)
# Step 2: Create essential files
files = [
 "app.py",
 "models.py",
 "forms.py",
 "requirements.txt",
 "templates/base.html",
 "templates/home.html",
 "templates/about.html",
 "templates/contact.html",
 "templates/login.html",
 "templates/register.html",
 "templates/students.html"
]
for file in files:
    with open(file, "w") as f:
        pass # Create empty file
print("Project structure and files created.")
# Out:
# Project structure and files created.

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# d:\VSCODE FILES\Javier\Lab10_Building Web Applications with Flask
# ['app.py', 'flask_app', 'forms.py', 'models.py', 'requirements.txt', 'static', 'templates', 'Untitled-1.ipynb']
